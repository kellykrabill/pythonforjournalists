# %% [markdown]
# ## Ohio data for COVID-19 cases within DODD
#
# - This dataset came from Ohio Association of County Boards through an email from Erich Hiner, the Communications Director
# - This dataset describes the total number of COVID-19 cases in Ohio for all age groups for individuals with developmental disabilities
# - This dataset describes the living situation with indviduals with developmental disabilities who have tested positive for COVID-19
# - I plan to compare these numbers with the Ohio COVID-19 cases, specifically cases in congregate settings and ages 21-30 and 51-60, which are the highest number for both datasets

# %%
import pandas as pd
df = pd.read_csv('ohio-dodd-covid-data.csv')

# %%
df.head(10)
# Out:
#   Total DD Positive Cases (start of pandemic to Feb. 24, 2021)  \
# 0                                              4,757
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
#
#    Total DD Deaths (start on pandemic to Feb. 24, 2021)  Unnamed: 2  \
# 0                                              199.0            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
# 5                                                NaN            NaN
# ...

# %%
df.tail(10)
# Out:
#   Total DD Positive Cases (start of pandemic to Feb. 24, 2021)  \
# 0                                              4,757
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
#
#    Total DD Deaths (start on pandemic to Feb. 24, 2021)  Unnamed: 2  \
# 0                                              199.0            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
# 5                                                NaN            NaN
# ...

# %% [markdown]
# df.dtypes

# %% [markdown]
# [Ohio DODD Cases](https://docs.google.com/spreadsheets/d/1Y7NPq1ysGui2aB7NlVrJCWwTKWH5urymfudH80rdZN8/edit?usp=sharing)

# %%
df.shape
# Out:
# (7, 10)

# %% [markdown]
# ## Ohio data for COVID-19 cases
#
# - This dataset came from the Ohio Department of Health's website under https://coronavirus.ohio.gov/wps/portal/gov/covid-19/dashboards
# - This dataset describes each counties COVID-19 cases in Ohio for all age groups
# - I plan to compare these numbers with the Ohio COVID-19 DODD cases, specifically ages 21-30 and 51-60, which are the highest number for both datasets
# - I plan to crunch the numbers to have each age range listed and possibly each county listed

# %%
import pandas as pd
df = pd.read_csv('covid-death-data-county-of-residence.csv')

# %%
df.head(10)
# Out:
#                                                                                                             COVIDDeathData_CountyOfResidence
# County Sex Age Range Onset Date Admission Date Date Of Death Case Count Hospitalized Count  Death Due To Illness Count - County Of Residence
# Adams  NaN 0-19      2020-12-10 NaN            NaN           2          0                                                                  0
#                      2020-12-11 NaN            NaN           1          0                                                                  0
#                      2021-01-18 NaN            NaN           1          0                                                                  0
#            20-29     2020-12-05 NaN            NaN           1          0                                                                  0
# ...

# %%
df.tail(10)
# Out:
#                                                COVIDDeathData_CountyOfResidence
# Lake       Female 80    NaN NaN 2021-03-13 0 0                                1
#            Male   40-49 NaN NaN 2021-03-13 0 0                                1
# Licking    Female 80    NaN NaN 2021-03-13 0 0                                1
# Mercer     Male   70-79 NaN NaN 2021-03-13 0 0                                1
# Montgomery Male   80    NaN NaN 2021-03-13 0 0                                1
# Clermont   Female 80    NaN NaN 2021-03-14 0 0                                1
# Cuyahoga   Female 80    NaN NaN 2021-03-14 0 0                                1
# Darke      Male   80    NaN NaN 2021-03-14 0 0                                1
# Cuyahoga   Female 80    NaN NaN 2021-03-15 0 0                                1
# Williams   Male   80    NaN NaN 2021-03-15 0 0                                1

# %% [markdown]
# [Ohio COVID Cases](https://coronavirus.ohio.gov/wps/portal/gov/covid-19/dashboards)

# %%
df.shape
# Out:
# (9, 4)
