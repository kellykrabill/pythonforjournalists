# %%
import pandas as pd
df = pd.read_csv('ohio-dodd-covid-data.csv')

# %%
df.head(10)
# Out:
#   Total DD Positive Cases (start of pandemic to Feb. 24, 2021)  \
# 0                                              4,757
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
#
#    Total DD Deaths (start on pandemic to Feb. 24, 2021)  Unnamed: 2  \
# 0                                              199.0            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
# 5                                                NaN            NaN
# ...

# %%
df.tail(10)
# Out:
#   Total DD Positive Cases (start of pandemic to Feb. 24, 2021)  \
# 0                                              4,757
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
#
#    Total DD Deaths (start on pandemic to Feb. 24, 2021)  Unnamed: 2  \
# 0                                              199.0            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
# 5                                                NaN            NaN
# ...

# %% [markdown]
# df.dtypes

# %% [markdown]
# [Ohio DODD Cases](https://docs.google.com/spreadsheets/d/1Y7NPq1ysGui2aB7NlVrJCWwTKWH5urymfudH80rdZN8/edit?usp=sharing)

# %%
df.shape
# Out:
# (7, 10)

# %%
import pandas as pd
df = pd.read_csv('ohio-covid-data-age-range.csv')

# %%
df.head(10)
# Out:
#   Ohio's Data             Unnamed: 1              Unnamed: 2    Unnamed: 3
# 0        Ages  Total Number of Cases  Total Hospitalizations  Total Deaths
# 1        0-19                127,507                   1,202             4
# 2       20-29                178,840                   1,971            21
# 3       30-39                148,924                   2,589            88
# 4       40-49                142,430                   3,972           232
# 5       50-59                149,629                   7,252           860
# 6       60-69                116,695                  11,007         2,480
# 7       70-79                 68,329                  12,182         4,715
# 8         80+                 51,132                  11,036         9,262

# %%
df.tail(10)
# Out:
#   Ohio's Data             Unnamed: 1              Unnamed: 2    Unnamed: 3
# 0        Ages  Total Number of Cases  Total Hospitalizations  Total Deaths
# 1        0-19                127,507                   1,202             4
# 2       20-29                178,840                   1,971            21
# 3       30-39                148,924                   2,589            88
# 4       40-49                142,430                   3,972           232
# 5       50-59                149,629                   7,252           860
# 6       60-69                116,695                  11,007         2,480
# 7       70-79                 68,329                  12,182         4,715
# 8         80+                 51,132                  11,036         9,262

# %% [markdown]
# [Ohio COVID Cases](https://docs.google.com/spreadsheets/d/1_BgEw1-8Gt34EJ-nSPDGfaSy4gS_Sf_rIsZ-3dh-9SQ/edit?usp=sharing)

# %%
df.shape
# Out:
# (9, 4)
