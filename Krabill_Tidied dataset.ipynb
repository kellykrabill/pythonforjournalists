# %% [markdown]
# ## Raw Dataset 1
# - This dataset represents COVID-19 cases for individuals with developmental disabilities in Ohio from the start of the pandemic until Feb. 24 2021.
# - Source: Erich Hiner, Communications Director at Ohio Association of County Boards
# - Raw dataset link is [here](https://drive.google.com/file/d/13fEciSepCZ2g61oD97LnEY5ums6I1IOP/view?usp=sharing)

# %%
import pandas as pd
df = pd.read_csv('ohio_dodd_covid_data.csv')

# %%
df.head(10)
# Out:
#   Total DD Positive Cases (start of pandemic to Feb. 24, 2021)  \
# 0                                              4,757
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
#
#    Total DD Deaths (start on pandemic to Feb. 24, 2021)  Unnamed: 2  \
# 0                                              199.0            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
# 5                                                NaN            NaN
# ...

# %%
df.tail(10)
# Out:
#   Total DD Positive Cases (start of pandemic to Feb. 24, 2021)  \
# 0                                              4,757
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
#
#    Total DD Deaths (start on pandemic to Feb. 24, 2021)  Unnamed: 2  \
# 0                                              199.0            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
# 5                                                NaN            NaN
# ...

# %%
df.shape
# Out:
# (8, 8)

# %% [markdown]
# ## Tidied Dataset 1
# - I removed age ranges 0-20 and 70&up.
# - I removed living situations of positive cases of individuals living alone or living with family.
# - My story will talk about individuals living in congregate settings and ICF settings from the age range 51-60 for the most part, but I may compare different age ranges as well.
# - Tidied dataset link is [here](https://docs.google.com/spreadsheets/d/1nJfwrfLNwLLlCVbaj65w8n9yGO1Ua8xLpVrKLuU-ybs/edit#gid=0)

# %%
import pandas as pd
df = pd.read_csv('python_krabill_covid_dodd_data.csv')

# %%
df.head(10)
# Out:
#                             Total DD positive cases   Total DD deaths   \
# 0                                              4,757             199.0
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4                                                NaN               NaN
# 5  *Defined for COVID-tracking purposes as any ph...               NaN
# 6  **Licensed Intermediate Care Facility for the ...               NaN
# 7  Data is from the start of the pandemic to Feb ...               NaN
#
#   Age range of positive cases  Total positive cases by age range  \
# 0                       21-30                              767.0
# 1                       31-40                              690.0
# 2                       41-50                              732.0
# 3                       51-60                              896.0
# ...

# %%
df.tail(10)
# Out:
#                             Total DD positive cases   Total DD deaths   \
# 0                                              4,757             199.0
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4                                                NaN               NaN
# 5  *Defined for COVID-tracking purposes as any ph...               NaN
# 6  **Licensed Intermediate Care Facility for the ...               NaN
# 7  Data is from the start of the pandemic to Feb ...               NaN
#
#   Age range of positive cases  Total positive cases by age range  \
# 0                       21-30                              767.0
# 1                       31-40                              690.0
# 2                       41-50                              732.0
# 3                       51-60                              896.0
# ...

# %%
df.shape
# Out:
# (7, 10)

# %% [markdown]
# ## Raw Dataset 2
# - This dataset represents COVID-19 cases in Ohio from the start of the pandemic until April 6 2021. Ohio COVID Dashboard did not have cases broken out by date, so this data does not end Feb. 24 2021 like Raw Dataset 1 does.
# - Source: [Ohio Department of Health COVID Dashboard](https://coronavirus.ohio.gov/wps/portal/gov/covid-19/dashboards)
# - Raw dataset link is [here](https://drive.google.com/file/d/1WiM7qcLtfgQIgU_oCh7tkSdd2Wr-Y2_Q/view?usp=sharing)

# %%
import pandas as pd
df = pd.read_csv('ohio_data_age_range.csv')

# %%
df.head(10)
# Out:
#   Total positive cases                        Age range of positive cases  \
# 0            1,030,864                                               0-19
# 1                  NaN                                              20-29
# 2                  NaN                                              30-39
# 3                  NaN                                              40-49
# 4                  NaN                                              50-59
# 5                  NaN                                              60-69
# 6                  NaN                                              70-79
# 7                  NaN                                                80+
# 8                  NaN  Data is from the start of the pandemic through...
# 9                  NaN  Source: https://coronavirus.ohio.gov/wps/porta...
#
#   Total positive cases by age range Total hospitalizations by age range  \
# 0                           135,675                               1,302
# ...

# %%
df.tail(10)
# Out:
#   Total positive cases                        Age range of positive cases  \
# 0            1,030,864                                               0-19
# 1                  NaN                                              20-29
# 2                  NaN                                              30-39
# 3                  NaN                                              40-49
# 4                  NaN                                              50-59
# 5                  NaN                                              60-69
# 6                  NaN                                              70-79
# 7                  NaN                                                80+
# 8                  NaN  Data is from the start of the pandemic through...
# 9                  NaN  Source: https://coronavirus.ohio.gov/wps/porta...
#
#   Total positive cases by age range Total hospitalizations by age range  \
# 0                           135,675                               1,302
# ...

# %%
df.shape
# Out:
# (10, 5)

# %% [markdown]
# ## Tidied Dataset 2
# - I removed age ranges 0-19, 70-79 and 80.
# - I removed total hospitalizations by age range and total deaths by age range.
# - I will compare this data of Ohio COVID cases to Ohio COVID cases of indivudals with developmental disabilities, focusing on age range 50-59.
# - Tidied dataset link is [here](https://drive.google.com/file/d/1IRHmHRHxl8TaSS-cht3WijytVnx5OWKB/view?usp=sharing)

# %%
import pandas as pd
df = pd.read_csv('clean_ohio_data_age_range.csv')

# %%
df.head(10)
# Out:
#                                 Total positive cases Total deaths  \
# 0                                            773,006        3,992
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3                                                NaN          NaN
# 4                                                NaN          NaN
# 5                                                NaN          NaN
# 6                                                NaN          NaN
# 7                                                NaN          NaN
# 8  Data is from the start of the pandemic through...          NaN
# 9  Source: https://coronavirus.ohio.gov/wps/porta...          NaN
#
#   Age range of positive cases Total positive cases by age range
# 0                       20-29                           188,760
# 1                       30-39                           157,204
# ...

# %%
df.tail(10)
# Out:
#                                 Total positive cases Total deaths  \
# 0                                            773,006        3,992
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3                                                NaN          NaN
# 4                                                NaN          NaN
# 5                                                NaN          NaN
# 6                                                NaN          NaN
# 7                                                NaN          NaN
# 8  Data is from the start of the pandemic through...          NaN
# 9  Source: https://coronavirus.ohio.gov/wps/porta...          NaN
#
#   Age range of positive cases Total positive cases by age range
# 0                       20-29                           188,760
# 1                       30-39                           157,204
# ...

# %%
df.shape
# Out:
# (10, 4)
